# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamorgado2/Digitalizacion/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int (input("Dime el valor del ladoA"))
ladoB = int (input("Dime el valor del ladoB"))
ladoC = int (input("Dime el valor del ladoC"))

#Cálculo del semiperímetro
s= (ladoA+ladoB+ladoC/2)

#Cálculo del área
a= (s*(s-ladoA)*(s-ladoB)*(s-ladoC)**0.5)
#Imprimimos el resultado
print("El resultado del semiperimetro es:" , s)
print("El resultado del area es:" , a)
